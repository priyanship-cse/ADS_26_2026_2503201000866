# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,15,30,25]

plt.plot(x, y)
plt.show()

# %%
months = ["jan" , "feb" , "Mar" , "Apr" , "May"]
sales = [100 ,150,120,180,200]

plt.plot(months , sales)
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
# for color 
plt.plot(
    months,sales,color ="red",linestyle = "--" , linewidth = 5 , marker = "o"
)

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May"]

sales_2025 = [100, 150, 120, 180, 200]
sales_2026 = [120, 170, 150, 200, 230]

plt.plot(months, sales_2025, marker="o", label="2025")
plt.plot(months, sales_2026, marker="s", label="2026")

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
student = ["Riya" , "Riyan" , "Arya" , "Aryan" ]
marks = [48,80,59 ,90 ]

plt.bar(student, marks , width = 0.8)
plt.title("Student Marks")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %%
plt.barh(student,marks)
plt.show()

# %%
students = ["A" , "B" , "C" , "D"]
python = [80,70,90,60]
java = [70,75,85,80]
import numpy as np

x = np.arange(len(students))
width = 0.35
plt.bar(x-width/2 , python , width , label = "Python")
plt.bar(x+width/2 , java , width , label = "Java")
plt.xticks(x,students)
plt.legend()
plt.show()

# %%
subject = ["AI" , "JAVA" , "PYTHON" , "SQL"]
hours = [30,25,45,10]

plt.pie(hours, labels = subject)
plt.show()

# %%
subjects = ["Maths","Science","English","Hindi"]
hours = [5,3,4,2]
exlode = (0.1,0,0,0)
mycolors = ["pink","grey","skyblue","lightgreen"]
plt.pie(hours, labels=subjects, explode=exlode, colors=mycolors,
        startangle=90, shadow=True, autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()
